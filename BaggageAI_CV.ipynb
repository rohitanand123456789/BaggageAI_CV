# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
back_img = cv2.imread('/content/drive/My Drive/BAGGAGE_20180811_175323_83216_B_1.jpg')
threat_img= cv2.imread('/content/drive/My Drive/BAGGAGE_20170522_113049_80428_A.jpg')

# %%
cv2_imshow(back_img)
# Out:
# <PIL.Image.Image image mode=RGB size=290x377 at 0x7F67C198BB90>

# %%
cv2_imshow(threat_img)
# Out:
# <PIL.Image.Image image mode=RGB size=232x768 at 0x7F67C00895D0>

# %%
print (back_img.shape)
print (threat_img.shape)
# Out:
# (377, 290, 3)
# (768, 232, 3)

# %%
img1 = cv2.resize(back_img,(800,600))
img2 = cv2.resize(threat_img,(800,600))

# %%
import imutils

# %%
img2 = imutils.rotate(img2, angle=45)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F67BFF98110>

# %%
blended = cv2.addWeighted(img1, 0.6, img2, 0.4, 0)
cv2_imshow(blended)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F67BFF57CD0>
